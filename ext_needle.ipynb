       '86449bc7905c', '8697c18cda1e', '8712397c0301', '87bda1cc55cf',
       '87c3dacd4df5', '887b190beddd', '88d578f61e3c', '898aefe9302d',
       '89be3999c095', '8cda8b3ec2ab', '8d1b0da5e426', '8db38a3a3f2a',
       '8e6a6f1e1f32', '8f7a017f146d', '903f70f4c2ed', '904048618192',
       '90b5c0496c69', '930f318497d1', '9343271c84c3', '93c4c3b297d5',
       '93fa1b6c2ca6', '940ad9f7ee1a', '945e92bb9a96', '95d4b9fdc569',
       '96f475bbf2b7', '990cf8655739', '994bc0cbdd77', '9adf7156adbd',
       '9b6f7e6720d6', '9bfd4b516169', '9e8d2b5f8741', '9fbe006d3bac',
       'a1112a84b8e5', 'a2573e5811ad', 'a26aaa09a903', 'a35a0358221e',
       'a51e65d95f22', 'a6c5113f7af3', 'a7febeb09fac', 'a83bdc6e5abd',
       'a8b873994b1b', 'a957b3d9284d', 'a9a721a257ae', 'aac0f5aed8c1',
       'aaf0ad2bfade', 'ab809f5de5df', 'abfb15629fda', 'aca74d6502ad',
       'ad446934b6ee', 'ae7e3edac230', 'b091d30b9a68', 'b19d5c5d052a',
       'b2275eebfb6c', 'b33b79b3bff2', 'b6820e6fb2a0', 'b84cb39f3ac5',
       'baa3d09885db', 'bad1fd6eafcc', 'baddc2e159e5', 'bb2e56eae59f',
       'bb56268b0fe7', 'bd31565fc0f0', 'bf1aa845a667', 'bf3b26a90ab0',
       'bfcbc350ed65', 'c00edc8884e7', 'c06f777400e9', 'c1a330ea8828',
       'c1c7458a6e7f', 'c1df05f6a7cf', 'c289d9a823d6', 'c2dc033669f4',
       'c2de72e699c8', 'c41209dc3f44', 'c41844b783a6', 'c450eb0f6759',
       'c45536572f3f', 'c478f0b2e6f2', 'c4dd4359f43e', 'c4fa887772a0',
       'c5117b8d695d', 'c64af5a43670', 'c9c208e64c14', 'cc7499393fb4',
       'ccdf663b52e8', 'cd0fde54c313', 'ce5063563f46', 'cf1783e8f2d0',
       'd069f847fbdb', 'd0f9af02c1d7', 'd13ee2edf958', 'd1c0698de850',
       'd201e5369761', 'd20b6847e2ab', 'd2a50942e725', 'd4d4b88b9124',
       'd50a514de680', 'd540e4ad0d4c', 'd56fae028d9d', 'd832d5565a71',
       'd9e3c966a6b7', 'dc92c7c1684a', 'dcdc88ada069', 'dd2fbe5d9d14',
       'de7bfaa084fe', 'e006b9012ad4', 'e09912699b23', 'e10b3d41d6f7',
       'e142e5fa9e8a', 'e14787cfe39d', 'e1bda4429944', 'e413be23b7d2',
       'e4219a7e8293', 'e4822b1268ff', 'e4912bcefad3', 'e4e7056aa326',
       'e51594b589e8', 'e5abe5b0f4a9', 'e5b07d788a04', 'e624bd5f19ed',
       'e73d4d525dd4', 'e84723092bdd', 'eb06062316ea', 'eb2fe21559a7',
       'eb63e0f4df66', 'ec6061496fce', 'ec61f0965614', 'edf919babe58',
       'edfe6c9b6a0b', 'ee82251f9bc0', 'eee16bde1ede', 'f0de868619b6',
       'f31879d61800', 'f31ab378dc13', 'f3c10918b22f', 'f462a458282a',
       'f46b781d6d7a', 'f563b6dc9056', 'f71ba1f5f9a3', 'f71bacbb3379',
       'f773d7b380a5', 'f99f4067b9b8', 'fad6049666be', 'fb06e1cb4ecc',
       'fcc18a733347', 'fcdf68613224', 'fe5032b0f869', 'fefaf1582ea7',
       'ff3c1936a0dd', 'ffc70eefe8c6', 'ffde38ad6974']

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import config
import designimg as d
import dataset as a
import glob


idx = np.random.choice(len(hard_samples))
config.APPLY_NEEDLE = False
config.INVERT_OFF_CHANNELS = True
i = a.SetiDataset([f'{config.RESIZED_IMAGE_PATH}train/{hard_samples[idx]}.npy'], targets = [0], ids =[0], resize=None, augmentations = True)[0]
plt.figure(figsize = (7,7))
plt.imshow(i['images'][0])
plt.show()
plt.figure(figsize = (7,7))
plt.imshow(i['images'][1])
plt.show()
plt.figure(figsize = (7,7))
plt.imshow(i['images'][2])
plt.show()

# config.APPLY_NEEDLE = False
# config.INVERT_OFF_CHANNELS = True
# i = a.SetiDataset([f'{config.RESIZED_IMAGE_PATH}train/{hard_samples[idx]}.npy'], targets = [0], ids =[0], resize=None, augmentations = False)[0]
# plt.figure(figsize = (7,7))
# plt.imshow(i['images'][0])
# plt.show()
# plt.imshow(i['images'][1])
# plt.show()
# plt.imshow(i['images'][2])
# plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import config
import designimg as d
import dataset as a
import glob


idx = 0
config.APPLY_NEEDLE = False
config.INVERT_OFF_CHANNELS = False
i = a.SetiDataset([f'{config.RESIZED_IMAGE_PATH}train/{hard_samples[idx]}.npy'], targets = [0], ids =[0], resize=None, augmentations = False)[0]
plt.figure(figsize = (10,10))
plt.imshow(i['images'][0])
plt.show()

config.APPLY_NEEDLE = False
config.INVERT_OFF_CHANNELS = True
i = a.SetiDataset([f'{config.RESIZED_IMAGE_PATH}train/{hard_samples[idx]}.npy'], targets = [0], ids =[0], resize=None, augmentations = False)[0]
plt.figure(figsize = (10,10))
plt.imshow(i['images'][0])
plt.show()
# Out:
# error creating /mnt/gfs/gv1/project_sonar_data/seti/resized_images_seti/256258
# folder exists, make sure this call is from inference.py
# 3.4653863e-10 1.0
# -3.7888224e-08 1.0

# %%
f'{config.RESIZED_IMAGE_PATH}train/'
# Out:
# '/mnt/gfs/gv1/project_sonar_data/seti/resized_images_seti/256258/train/'

# %%
ls /mnt/gfs/gv1/project_sonar_data/seti/resized_images_seti/256258/train/ -U | head -20
# Out:
# 3b9ff5c10b3b.npy
# 3197414ebc35.npy
# 31f5733437b3.npy
# 339d8243e83d.npy
# 386a917a8961.npy
# 30d8c0df51bb.npy
# 37a0e5c6b9b7.npy
# 38b09ea8e0d7.npy
# 3559ff2d18e8.npy
# 304e2315b5dd.npy
# 3cfc4637b093.npy
# 365c9dbf717e.npy
# 341ee64bac4c.npy
# 3065b9df1dde.npy
# 3806a3cee069.npy
# 363cae8ec2c9.npy
# 330169840de8.npy
# 34237693e367.npy
# 368c65ba26dd.npy
# 36aa7926a538.npy
# ls: write error: Broken pipe

# %%
import cv2
import random
e = cv2.imread(glob.glob('/mnt/gfs/gv1/project_sonar_data/seti/ext/ext_needles/primary_small/train/squiggle/*.png')[random.choice(range(100))], cv2.IMREAD_GRAYSCALE)
# e
plt.imshow(e)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17ff754eeaea> in <module>
#       1 import cv2
#       2 import random
# ----> 3 e = cv2.imread(glob.glob('/mnt/gfs/gv1/project_sonar_data/seti/ext/ext_needles/primary_small/train/squiggle/*.png')[random.choice(range(100))], cv2.IMREAD_GRAYSCALE)
#       4 # e
#       5 plt.imshow(e)
#
# NameError: name 'glob' is not defined

# %%
'sa'.replace('a', '')
# Out:
# 's'

# %%
# Out:
# (258, 256) (258, 256)

# %%
o = np.load(f'{config.DATA_PATH}train/3/30d8c0df51bb.npy')[0].astype(np.float32)
plt.figure()
plt.imshow(o)
plt.show()
