# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import config
import designimg as d
import dataset as a
import glob



config.APPLY_NEEDLE = True
config.INVERT_OFF_CHANNELS = True
i = a.SetiDataset([f'{config.RESIZED_IMAGE_PATH}train/150be16760e4.npy'], targets = [0], ids =[0], resize=None, augmentations = True)[0]
plt.figure(figsize = (10,10))
plt.imshow(i['images'][0])
plt.show()

config.APPLY_NEEDLE = False
config.INVERT_OFF_CHANNELS = False
i = a.SetiDataset([f'{config.RESIZED_IMAGE_PATH}train/150be16760e4.npy'], targets = [0], ids =[0], resize=None, augmentations = False)[0]
plt.figure()
plt.imshow(i['images'][0])
plt.show()
# Out:
# 1
# 0

# %%
f'{config.RESIZED_IMAGE_PATH}train/'
# Out:
# '/mnt/gfs/gv1/project_sonar_data/seti/resized_images_seti/256258/train/'

# %%
ls /mnt/gfs/gv1/project_sonar_data/seti/resized_images_seti/256258/train/ -U | head -20
# Out:
# 3b9ff5c10b3b.npy
# 3197414ebc35.npy
# 31f5733437b3.npy
# 339d8243e83d.npy
# 386a917a8961.npy
# 30d8c0df51bb.npy
# 37a0e5c6b9b7.npy
# 38b09ea8e0d7.npy
# 3559ff2d18e8.npy
# 304e2315b5dd.npy
# 3cfc4637b093.npy
# 365c9dbf717e.npy
# 341ee64bac4c.npy
# 3065b9df1dde.npy
# 3806a3cee069.npy
# 363cae8ec2c9.npy
# 330169840de8.npy
# 34237693e367.npy
# 368c65ba26dd.npy
# 36aa7926a538.npy
# ls: write error: Broken pipe

# %%
import cv2
import random
e = cv2.imread(glob.glob('/mnt/gfs/gv1/project_sonar_data/seti/ext/ext_needles/primary_small/train/squiggle/*.png')[random.choice(range(100))], cv2.IMREAD_GRAYSCALE)
# e
plt.imshow(e)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-17ff754eeaea> in <module>
#       1 import cv2
#       2 import random
# ----> 3 e = cv2.imread(glob.glob('/mnt/gfs/gv1/project_sonar_data/seti/ext/ext_needles/primary_small/train/squiggle/*.png')[random.choice(range(100))], cv2.IMREAD_GRAYSCALE)
#       4 # e
#       5 plt.imshow(e)
#
# NameError: name 'glob' is not defined

# %%
'sa'.replace('a', '')
# Out:
# 's'

# %%
# Out:
# (258, 256) (258, 256)

# %%
o = np.load(f'{config.DATA_PATH}train/3/30d8c0df51bb.npy')[0].astype(np.float32)
plt.figure()
plt.imshow(o)
plt.show()
