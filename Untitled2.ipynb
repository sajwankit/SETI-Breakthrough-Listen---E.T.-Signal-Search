# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
import config
import designimg as d
import dataset as a
import glob
# Out:
# error creating /mnt/gfs/gv1/project_sonar_data/seti/resized_images_seti/256258
# folder exists, make sure this call is from inference.py

# %%
ls /mnt/gfs/gv1/project_sonar_data/seti/resized_images_seti/256258/train/ -U | head -10
# Out:
# 3b9ff5c10b3b.npy
# 3197414ebc35.npy
# 31f5733437b3.npy
# 339d8243e83d.npy
# 386a917a8961.npy
# 30d8c0df51bb.npy
# 37a0e5c6b9b7.npy
# 38b09ea8e0d7.npy
# 3559ff2d18e8.npy
# 304e2315b5dd.npy
# ls: write error: Broken pipe

# %%
i = a.SetiDataset([f'{config.RESIZED_IMAGE_PATH}train/3b9ff5c10b3b.npy'], targets = [1], ids =[0], resize=None, augmentations = True)[0]
plt.figure(figsize = (5,5))
plt.imshow(i['images'][0])
plt.show()

# %%
i = a.SetiDataset([f'{config.RESIZED_IMAGE_PATH}train/3b9ff5c10b3b.npy'], targets = [1], ids =[0], resize=None, augmentations = False)[0]
plt.figure()
plt.imshow(i['images'][0])
plt.show()

# %%
o = np.load(f'{config.DATA_PATH}train/3/30d8c0df51bb.npy')[0].astype(np.float32)
plt.figure()
plt.imshow(o)
plt.show()
